# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# PyTorch Lightning
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from pytorch_lightning.loggers import WandbLogger
# from pytorch_lightning.callbacks import EarlyStopping, LearningRateMonitor

import wandb
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import MinMaxScaler

import netCDF4

# %%
AVAIL_GPUS = min(1, torch.cuda.device_count())
BATCH_SIZE = 128 if AVAIL_GPUS else 64

# %%
pl.seed_everything(125)
# Out:
# Global seed set to 125
# 125

# %% [markdown]
# ## Load Data

# %%
sho = netCDF4.Dataset('../data/sho_friction2.nc').variables
t_sho = np.array(sho['t'][:], dtype=np.float32)
s_sho = np.array(sho['s'][:], dtype=np.float32)
v_sho = np.array(sho['v'][:], dtype=np.float32)

# %%
plt.figure(figsize=(10, 6), dpi=150)
plt.plot(t_sho, s_sho)
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=150)
plt.plot(t_sho, v_sho)
plt.show()

# %%
# X_total = np.column_stack([s_sho, v_sho])
X_total = s_sho.reshape(-1, 1)
sc = MinMaxScaler()
X_normalized = sc.fit_transform(X_total)

# %%
plt.figure(figsize=(10, 6), dpi=150)
plt.plot(t_sho, X_normalized[:,0])
plt.show()

# %%
def sliding_window(data, seq_length):
    x = []
    y = []

    for i in range(len(data)-seq_length-1):
        _x = data[i:(i+seq_length)]
        _y = data[i+seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

# %%
def train_test(df, test_periods):
    train = df[:-test_periods]
    test = df[-test_periods:]
    return train, test

# %%
X, y = sliding_window(X_normalized, 10)

# %%
X.shape
# Out:
# (190, 10, 1)

# %%
y.shape
# Out:
# (190, 1)

# %%
N = X.shape[0]
N_train = 100
N_test = N - N_train

X_train = X[:N_train]
y_train = y[:N_train]
X_test = X[N_train:150]
y_test = y[N_train:150]

# %%
class NewtonData(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
    
    def __len__(self):
        return self.X.shape[0]
    
    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
ds_train = NewtonData(X_train, y_train)
ds_val = NewtonData(X_test, y_test)

# %%
len(ds_train)
# Out:
# 100

# %%
len(ds_val)
# Out:
# 50

# %%
ds_train[0][0].shape
# Out:
# (10, 1)

# %%
dl_train = DataLoader(ds_train, batch_size=10, shuffle=True)

# %%
ds_train[0]
# Out:
# (array([[1.        ],
#         [0.9694807 ],
#         [0.8905688 ],
#         [0.7718029 ],
#         [0.6256945 ],
#         [0.46729314],
#         [0.3126407 ],
#         [0.17715085],
#         [0.07407665],
#         [0.01321888]], dtype=float32),
#  array([0.], dtype=float32))

# %%
class MLP(nn.Module):

    def __init__(self, input_size, output_size):
        super(MLP, self).__init__()
        
        self.input_size = input_size
        self.net = nn.Sequential(
            nn.Linear(input_size, 128),
            nn.ReLU(inplace=True),
            nn.Linear(128, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 128),
            nn.ReLU(inplace=True),
            nn.Linear(128, output_size)
        )
        
    def forward(self, x):
        return self.net(x.view(-1, 10))

# %%
model = MLP(input_size=10, output_size=1)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
model.eval()
dl_iter = iter(dl_train)
x_one, y_one = next(dl_iter)

# %%
x_one.shape
# Out:
# torch.Size([10, 10, 1])

# %%
y_one.shape
# Out:
# torch.Size([10, 1])

# %%
model(x_one).shape
# Out:
# torch.Size([10, 1])

# %%
epochs = 1000
model.train()
for epoch in range(epochs+1):
    for x, y in dl_train:
        y_hat = model(x)
        optimizer.zero_grad()
        loss = criterion(y_hat, y)
        loss.backward()
        optimizer.step()
        
    if epoch%100==0:
        print(f'epoch: {epoch:4} loss:{loss.item():10.8f}')
# Out:
# epoch:    0 loss:0.12603198
# epoch:  100 loss:0.00000139
# epoch:  200 loss:0.00000836
# epoch:  300 loss:0.00020110
# epoch:  400 loss:0.00001590
# epoch:  500 loss:0.00000101
# epoch:  600 loss:0.00000779
# epoch:  700 loss:0.00000673
# epoch:  800 loss:0.00000087
# epoch:  900 loss:0.00000156
# epoch: 1000 loss:0.00000053

# %%
model.eval()
# Out:
# MLP(
#   (net): Sequential(
#     (0): Linear(in_features=10, out_features=128, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=128, out_features=256, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=256, out_features=256, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=256, out_features=128, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
X, y = sliding_window(X_normalized, 10)

# %%
total_data = NewtonData(X, y)

# %%
dl = DataLoader(total_data, batch_size=len(total_data))
dl_iter = iter(dl)
X, y = next(dl_iter)

# %%
y.shape
# Out:
# torch.Size([190, 1])

# %%
t = t_sho[10:-1]
t.shape
# Out:
# (190,)

# %%
plt.plot(t, y.cpu().numpy())

# %%
y_pred = model(X)

# %%
plt.plot(t, y_pred.detach().numpy())

# %%
plt.figure(figsize=(10, 6), dpi=150)
plt.plot(t, y.cpu().numpy())
plt.plot(t, y_pred.detach().numpy())
plt.show()

# %%
X.shape
# Out:
# torch.Size([190, 10, 1])

# %%
t.shape
# Out:
# (190,)

# %%
N_extrap = 190
X_new = X[0]
X_new.shape
# Out:
# torch.Size([10, 1])

# %%
X_new.view(1,-1,1)
# Out:
# tensor([[[1.0000],
#          [0.9695],
#          [0.8906],
#          [0.7718],
#          [0.6257],
#          [0.4673],
#          [0.3126],
#          [0.1772],
#          [0.0741],
#          [0.0132]]])

# %%
y_ex = []
t_ex = []
dt = 1e-1
for i in range(N_extrap):
    y_new = model(X_new.view(1, -1, 1))
    X_new = torch.concat([X_new[1:], y_new])
    t_ex.append(t[0] + i * dt)
    y_ex.append(y_new.view(-1).detach().numpy())

# %%
# t_total = np.concatenate([t[0], t_ex])
t_total = t_ex
# y_pred_total = np.concatenate([y_pred.detach().numpy()[0:100], y_ex])
y_pred_total = y_ex

# %%
shoo = netCDF4.Dataset('../data/sho_friction3.nc').variables
t_shoo = np.array(shoo['t'][:], dtype=np.float32)
s_shoo = np.array(shoo['s'][:], dtype=np.float32)
v_shoo = np.array(shoo['v'][:], dtype=np.float32)

# %%
sc = MinMaxScaler()
s_shoo_new = sc.fit_transform(s_shoo.reshape(-1, 1))

# %%
plt.figure(figsize=(10, 6), dpi=300)
plt.plot(t, y.cpu().numpy(), '--', alpha=0.8)
plt.plot(t_total, y_pred_total, '--', alpha=0.8)
plt.plot(t_shoo[10:], s_shoo_new[10:], '--', alpha=0.8)

# plt.axvline(t[100], linestyle='--', color='r')
# plt.xlim([0, 20])
# plt.ylim([-0.1,1.1])
plt.show()
